# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Import Section

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer

from scipy.stats import norm
from scipy import stats
from sklearn.impute import KNNImputer

# %%
# read csv file
df=pd.read_csv("CarsRatings.csv" , index_col="Unnamed: 0")
df.head()
# Out:
#    Rate Adult Occupant Child Occupant Vulnerable Road Users Safety Assist  \
# 1     5            84%            89%                   81%           81%
# 2     5            87%            87%                   68%           88%
# 3     4            75%            84%                   70%           69%
# 4     5            84%            90%                   74%           84%
# 5     5            84%            89%                   71%           85%
#
#                                    Tested Model     Body Type  \
# 1  Jeep Grand Cherokee 2.0 PHEV 'Overland', LHD  - 5 door SUV
# 2                        CHERY OMODA5 1.6T, LHD         - SUV
# 3           Ford Puma 1.0 MHEV, 'Titanium', LHD  - 5 door SUV
# 4                 VW Amarok 2.0/Ford Ranger 3.0     - Pick-Up
# 5                               Discovery Sport  - 5 door SUV
#
#    Year Of Publication Kerb Weight VIN From Which Rating Applies  ...  \
# 1                 2022      2532kg         - all Grand Cherokees  ...
# 2                 2022      1423kg                  - all OMODA5  ...
# 3                 2022      1334kg              - all Ford Pumas  ...
# 4                 2022      2434kg    - all double cabin Rangers  ...
# 5                 2022      2123kg           - SALCP2FX2PH325732  ...
#
#   Isofix/i-Size-Rear Integrated Child Seat-Rear Airbag cut-off switch-Rear  \
# 1    Fitted_Standard              Not_Available             Not_Applicable
# 2    Fitted_Standard              Not_Available             Not_Applicable
# 3    Fitted_Standard              Not_Available             Not_Applicable
# 4    Fitted_Standard              Not_Available             Not_Applicable
# 5    Fitted_Standard              Not_Available             Not_Applicable
#
#   Seatbelt Reminder-Rear    Active Bonnet AEB Vulnerable Road Users  \
# 1        Fitted_Standard    Not_Available           Fitted_Standard
# 2        Fitted_Standard    Not_Available           Fitted_Standard
# 3        Fitted_Standard    Not_Available           Fitted_Standard
# 4        Fitted_Standard    Not_Available           Fitted_Standard
# 5        Fitted_Standard  Fitted_Standard           Fitted_Standard
#
#   AEB Pedestrian - Reverse   AEB Car-to-Car Speed Assistance  \
# 1            Not_Available  Fitted_Standard  Fitted_Standard
# 2          Fitted_Standard  Fitted_Standard  Fitted_Standard
# 3            Not_Available  Fitted_Standard  Fitted_Standard
# 4          Fitted_Standard  Fitted_Standard  Fitted_Standard
# 5            Not_Available  Fitted_Standard  Fitted_Standard
#
#   Lane Assist System
# 1    Fitted_Standard
# 2    Fitted_Standard
# 3    Fitted_Standard
# 4    Fitted_Standard
# 5    Fitted_Standard
#
# [5 rows x 53 columns]

# %%
# replace every nan as string to np.nan
df.replace("nan",np.nan,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311 entries, 1 to 311
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Rate                             311 non-null    int64
#  1   Adult Occupant                   311 non-null    object
#  2   Child Occupant                   311 non-null    object
#  3   Vulnerable Road Users            218 non-null    object
#  4   Safety Assist                    311 non-null    object
#  5   Tested Model                     311 non-null    object
#  6   Body Type                        311 non-null    object
#  7   Year Of Publication              311 non-null    int64
#  8   Kerb Weight                      311 non-null    object
#  9   VIN From Which Rating Applies    311 non-null    object
#  10  Class                            311 non-null    object
#  11  Front Airbag-Driver              311 non-null    object
#  12  Belt Pretensioner-Driver         311 non-null    object
#  13  Belt Loadlimiter-Driver          311 non-null    object
#  14  Knee Airbag-Driver               311 non-null    object
#  15  Side Head Airbag-Driver          311 non-null    object
#  16  Side Chest Airbag-Driver         311 non-null    object
#  17  Side Pelvis Airbag-Driver        311 non-null    object
#  18  Centre Airbag-Driver             126 non-null    object
#  19  Isofix/i-Size-Driver             311 non-null    object
#  20  Integrated Child Seat-Driver     311 non-null    object
#  21  Airbag cut-off switch-Driver     311 non-null    object
#  22  Seatbelt Reminder-Driver         311 non-null    object
#  23  Front Airbag-Passenger           311 non-null    object
#  24  Belt Pretensioner-Passenger      311 non-null    object
#  25  Belt Loadlimiter-Passenger       311 non-null    object
#  26  Knee Airbag-Passenger            311 non-null    object
#  27  Side Head Airbag-Passenger       311 non-null    object
#  28  Side Chest Airbag-Passenger      311 non-null    object
#  29  Side Pelvis Airbag-Passenger     311 non-null    object
#  30  Centre Airbag-Passenger          126 non-null    object
#  31  Isofix/i-Size-Passenger          311 non-null    object
#  32  Integrated Child Seat-Passenger  311 non-null    object
#  33  Airbag cut-off switch-Passenger  311 non-null    object
#  34  Seatbelt Reminder-Passenger      311 non-null    object
#  35  Front Airbag-Rear                311 non-null    object
#  36  Belt Pretensioner-Rear           311 non-null    object
#  37  Belt Loadlimiter-Rear            311 non-null    object
#  38  Knee Airbag-Rear                 311 non-null    object
#  39  Side Head Airbag-Rear            311 non-null    object
#  40  Side Chest Airbag-Rear           311 non-null    object
#  41  Side Pelvis Airbag-Rear          311 non-null    object
#  42  Centre Airbag-Rear               126 non-null    object
#  43  Isofix/i-Size-Rear               311 non-null    object
#  44  Integrated Child Seat-Rear       311 non-null    object
#  45  Airbag cut-off switch-Rear       311 non-null    object
#  46  Seatbelt Reminder-Rear           311 non-null    object
#  47  Active Bonnet                    311 non-null    object
#  48  AEB Vulnerable Road Users        127 non-null    object
#  49  AEB Pedestrian - Reverse         127 non-null    object
#  50  AEB Car-to-Car                   127 non-null    object
#  51  Speed Assistance                 311 non-null    object
#  52  Lane Assist System               311 non-null    object
# dtypes: int64(2), object(51)
# memory usage: 131.2+ KB

# %%
# TO-DO: remove  '%' in [Adult Occupant	Child Occupant,	Vulnerable Road Users,	Safety Assist] and change dtype to int
cols=['Adult Occupant', 'Child Occupant', 'Vulnerable Road Users', 'Safety Assist']

df['Adult Occupant']=df['Adult Occupant'].str.replace('%','')
df['Child Occupant']=df['Child Occupant'].str.replace('%','')
df['Safety Assist']=df['Safety Assist'].str.replace('%','')
df['Vulnerable Road Users']=df['Vulnerable Road Users'].str.replace('%','')
df['Kerb Weight']=df['Kerb Weight'].str.replace('kg','')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311 entries, 1 to 311
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Rate                             311 non-null    int64
#  1   Adult Occupant                   311 non-null    object
#  2   Child Occupant                   311 non-null    object
#  3   Vulnerable Road Users            218 non-null    object
#  4   Safety Assist                    311 non-null    object
#  5   Tested Model                     311 non-null    object
#  6   Body Type                        311 non-null    object
#  7   Year Of Publication              311 non-null    int64
#  8   Kerb Weight                      311 non-null    object
#  9   VIN From Which Rating Applies    311 non-null    object
#  10  Class                            311 non-null    object
#  11  Front Airbag-Driver              311 non-null    object
#  12  Belt Pretensioner-Driver         311 non-null    object
#  13  Belt Loadlimiter-Driver          311 non-null    object
#  14  Knee Airbag-Driver               311 non-null    object
#  15  Side Head Airbag-Driver          311 non-null    object
#  16  Side Chest Airbag-Driver         311 non-null    object
#  17  Side Pelvis Airbag-Driver        311 non-null    object
#  18  Centre Airbag-Driver             126 non-null    object
#  19  Isofix/i-Size-Driver             311 non-null    object
#  20  Integrated Child Seat-Driver     311 non-null    object
#  21  Airbag cut-off switch-Driver     311 non-null    object
#  22  Seatbelt Reminder-Driver         311 non-null    object
#  23  Front Airbag-Passenger           311 non-null    object
#  24  Belt Pretensioner-Passenger      311 non-null    object
#  25  Belt Loadlimiter-Passenger       311 non-null    object
#  26  Knee Airbag-Passenger            311 non-null    object
#  27  Side Head Airbag-Passenger       311 non-null    object
#  28  Side Chest Airbag-Passenger      311 non-null    object
#  29  Side Pelvis Airbag-Passenger     311 non-null    object
#  30  Centre Airbag-Passenger          126 non-null    object
#  31  Isofix/i-Size-Passenger          311 non-null    object
#  32  Integrated Child Seat-Passenger  311 non-null    object
#  33  Airbag cut-off switch-Passenger  311 non-null    object
#  34  Seatbelt Reminder-Passenger      311 non-null    object
#  35  Front Airbag-Rear                311 non-null    object
#  36  Belt Pretensioner-Rear           311 non-null    object
#  37  Belt Loadlimiter-Rear            311 non-null    object
#  38  Knee Airbag-Rear                 311 non-null    object
#  39  Side Head Airbag-Rear            311 non-null    object
#  40  Side Chest Airbag-Rear           311 non-null    object
#  41  Side Pelvis Airbag-Rear          311 non-null    object
#  42  Centre Airbag-Rear               126 non-null    object
#  43  Isofix/i-Size-Rear               311 non-null    object
#  44  Integrated Child Seat-Rear       311 non-null    object
#  45  Airbag cut-off switch-Rear       311 non-null    object
#  46  Seatbelt Reminder-Rear           311 non-null    object
#  47  Active Bonnet                    311 non-null    object
#  48  AEB Vulnerable Road Users        127 non-null    object
#  49  AEB Pedestrian - Reverse         127 non-null    object
#  50  AEB Car-to-Car                   127 non-null    object
#  51  Speed Assistance                 311 non-null    object
#  52  Lane Assist System               311 non-null    object
# dtypes: int64(2), object(51)
# memory usage: 131.2+ KB

# %%
df
# Out:
#      Rate Adult Occupant Child Occupant Vulnerable Road Users Safety Assist  \
# 1       5             84             89                    81            81
# 2       5             87             87                    68            88
# 3       4             75             84                    70            69
# 4       5             84             90                    74            84
# 5       5             84             89                    71            85
# ..    ...            ...            ...                   ...           ...
# 307     5             93             84                   NaN            60
# 308     5             96             84                   NaN            68
# 309     3             80             73                   NaN            25
# 310     4             85             73                   NaN            43
# 311     5             92             82                   NaN            85
#
#                                      Tested Model           Body Type  \
# 1    Jeep Grand Cherokee 2.0 PHEV 'Overland', LHD        - 5 door SUV
# 2                          CHERY OMODA5 1.6T, LHD               - SUV
# 3             Ford Puma 1.0 MHEV, 'Titanium', LHD        - 5 door SUV
# 4                   VW Amarok 2.0/Ford Ranger 3.0           - Pick-Up
# 5                                 Discovery Sport        - 5 door SUV
# ..                                            ...                 ...
# 307                    SEAT Ateca 1.6 diesel, LHD        - 5 door SUV
# 308                 VW Tiguan 2.0 TDI 110 kW, LHD          5 door SUV
# 309                                 Suzuki Baleno    5 door hatchback
# 310                                 Suzuki Baleno  - 5 door hatchback
# 311                                  Prius Hybrid    5 door hatchback
#
#      Year Of Publication Kerb Weight  \
# 1                   2022        2532
# 2                   2022        1423
# 3                   2022        1334
# 4                   2022        2434
# 5                   2022        2123
# ..                   ...         ...
# 307                 2016        1300
# 308                 2016        1531
# 309                 2016         890
# 310                 2016         890
# 311                 2016        1387
#
#                  VIN From Which Rating Applies  ... Isofix/i-Size-Rear  \
# 1                        - all Grand Cherokees  ...    Fitted_Standard
# 2                                 - all OMODA5  ...    Fitted_Standard
# 3                             - all Ford Pumas  ...    Fitted_Standard
# 4                   - all double cabin Rangers  ...    Fitted_Standard
# 5                          - SALCP2FX2PH325732  ...    Fitted_Standard
# ..                                         ...  ...                ...
# 307   - all Atecas of the specification tested  ...    Fitted_Standard
# 308  - all Tiguans of the specification tested  ...    Fitted_Standard
# 309                              - all Balenos  ...    Fitted_Standard
# 310                              - all Balenos  ...    Fitted_Standard
# 311                                - all Prius  ...    Fitted_Standard
#
#     Integrated Child Seat-Rear Airbag cut-off switch-Rear  \
# 1                Not_Available             Not_Applicable
# 2                Not_Available             Not_Applicable
# 3                Not_Available             Not_Applicable
# 4                Not_Available             Not_Applicable
# 5                Not_Available             Not_Applicable
# ..                         ...                        ...
# 307              Not_Available             Not_Applicable
# 308              Not_Available             Not_Applicable
# 309              Not_Available             Not_Applicable
# 310              Not_Available             Not_Applicable
# 311              Not_Available             Not_Applicable
#
#     Seatbelt Reminder-Rear    Active Bonnet AEB Vulnerable Road Users  \
# 1          Fitted_Standard    Not_Available           Fitted_Standard
# 2          Fitted_Standard    Not_Available           Fitted_Standard
# 3          Fitted_Standard    Not_Available           Fitted_Standard
# 4          Fitted_Standard    Not_Available           Fitted_Standard
# 5          Fitted_Standard  Fitted_Standard           Fitted_Standard
# ..                     ...              ...                       ...
# 307        Fitted_Standard    Not_Available                       NaN
# 308        Fitted_Standard  Fitted_Standard                       NaN
# 309        Fitted_Standard    Not_Available                       NaN
# 310        Fitted_Standard    Not_Available                       NaN
# 311        Fitted_Standard    Not_Available                       NaN
#
#     AEB Pedestrian - Reverse   AEB Car-to-Car Speed Assistance  \
# 1              Not_Available  Fitted_Standard  Fitted_Standard
# 2            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 3              Not_Available  Fitted_Standard  Fitted_Standard
# 4            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 5              Not_Available  Fitted_Standard  Fitted_Standard
# ..                       ...              ...              ...
# 307                      NaN              NaN  Fitted_Standard
# 308                      NaN              NaN       Not_Fitted
# 309                      NaN              NaN       Not_Fitted
# 310                      NaN              NaN       Not_Fitted
# 311                      NaN              NaN  Fitted_Standard
#
#     Lane Assist System
# 1      Fitted_Standard
# 2      Fitted_Standard
# 3      Fitted_Standard
# 4      Fitted_Standard
# 5      Fitted_Standard
# ..                 ...
# 307         Not_Fitted
# 308    Fitted_Standard
# 309      Not_Available
# 310      Not_Available
# 311    Fitted_Standard
#
# [311 rows x 53 columns]

# %%
#convert the columns to int
df['Adult Occupant'] = df['Adult Occupant'].astype('int64')
df['Child Occupant'] = df['Child Occupant'].astype('int64')
df['Vulnerable Road Users'] = df['Vulnerable Road Users'].fillna(0).astype('int64')
df['Safety Assist'] = df['Safety Assist'].astype('int64')
df['Kerb Weight'] = df['Kerb Weight'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 311 entries, 1 to 311
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Rate                             311 non-null    int64
#  1   Adult Occupant                   311 non-null    int64
#  2   Child Occupant                   311 non-null    int64
#  3   Vulnerable Road Users            311 non-null    int64
#  4   Safety Assist                    311 non-null    int64
#  5   Tested Model                     311 non-null    object
#  6   Body Type                        311 non-null    object
#  7   Year Of Publication              311 non-null    int64
#  8   Kerb Weight                      311 non-null    int64
#  9   VIN From Which Rating Applies    311 non-null    object
#  10  Class                            311 non-null    object
#  11  Front Airbag-Driver              311 non-null    object
#  12  Belt Pretensioner-Driver         311 non-null    object
#  13  Belt Loadlimiter-Driver          311 non-null    object
#  14  Knee Airbag-Driver               311 non-null    object
#  15  Side Head Airbag-Driver          311 non-null    object
#  16  Side Chest Airbag-Driver         311 non-null    object
#  17  Side Pelvis Airbag-Driver        311 non-null    object
#  18  Centre Airbag-Driver             126 non-null    object
#  19  Isofix/i-Size-Driver             311 non-null    object
#  20  Integrated Child Seat-Driver     311 non-null    object
#  21  Airbag cut-off switch-Driver     311 non-null    object
#  22  Seatbelt Reminder-Driver         311 non-null    object
#  23  Front Airbag-Passenger           311 non-null    object
#  24  Belt Pretensioner-Passenger      311 non-null    object
#  25  Belt Loadlimiter-Passenger       311 non-null    object
#  26  Knee Airbag-Passenger            311 non-null    object
#  27  Side Head Airbag-Passenger       311 non-null    object
#  28  Side Chest Airbag-Passenger      311 non-null    object
#  29  Side Pelvis Airbag-Passenger     311 non-null    object
#  30  Centre Airbag-Passenger          126 non-null    object
#  31  Isofix/i-Size-Passenger          311 non-null    object
#  32  Integrated Child Seat-Passenger  311 non-null    object
#  33  Airbag cut-off switch-Passenger  311 non-null    object
#  34  Seatbelt Reminder-Passenger      311 non-null    object
#  35  Front Airbag-Rear                311 non-null    object
#  36  Belt Pretensioner-Rear           311 non-null    object
#  37  Belt Loadlimiter-Rear            311 non-null    object
#  38  Knee Airbag-Rear                 311 non-null    object
#  39  Side Head Airbag-Rear            311 non-null    object
#  40  Side Chest Airbag-Rear           311 non-null    object
#  41  Side Pelvis Airbag-Rear          311 non-null    object
#  42  Centre Airbag-Rear               126 non-null    object
#  43  Isofix/i-Size-Rear               311 non-null    object
#  44  Integrated Child Seat-Rear       311 non-null    object
#  45  Airbag cut-off switch-Rear       311 non-null    object
#  46  Seatbelt Reminder-Rear           311 non-null    object
#  47  Active Bonnet                    311 non-null    object
#  48  AEB Vulnerable Road Users        127 non-null    object
#  49  AEB Pedestrian - Reverse         127 non-null    object
#  50  AEB Car-to-Car                   127 non-null    object
#  51  Speed Assistance                 311 non-null    object
#  52  Lane Assist System               311 non-null    object
# dtypes: int64(7), object(46)
# memory usage: 131.2+ KB

# %%
df['Vulnerable Road Users'] = df['Vulnerable Road Users'].replace(0,np.nan)

df
# Out:
#      Rate  Adult Occupant  Child Occupant  Vulnerable Road Users  \
# 1       5              84              89                   81.0
# 2       5              87              87                   68.0
# 3       4              75              84                   70.0
# 4       5              84              90                   74.0
# 5       5              84              89                   71.0
# ..    ...             ...             ...                    ...
# 307     5              93              84                    NaN
# 308     5              96              84                    NaN
# 309     3              80              73                    NaN
# 310     4              85              73                    NaN
# 311     5              92              82                    NaN
#
#      Safety Assist                                  Tested Model  \
# 1               81  Jeep Grand Cherokee 2.0 PHEV 'Overland', LHD
# 2               88                        CHERY OMODA5 1.6T, LHD
# 3               69           Ford Puma 1.0 MHEV, 'Titanium', LHD
# 4               84                 VW Amarok 2.0/Ford Ranger 3.0
# 5               85                               Discovery Sport
# ..             ...                                           ...
# 307             60                    SEAT Ateca 1.6 diesel, LHD
# 308             68                 VW Tiguan 2.0 TDI 110 kW, LHD
# 309             25                                 Suzuki Baleno
# 310             43                                 Suzuki Baleno
# 311             85                                  Prius Hybrid
#
#               Body Type  Year Of Publication  Kerb Weight  \
# 1          - 5 door SUV                 2022         2532
# 2                 - SUV                 2022         1423
# 3          - 5 door SUV                 2022         1334
# 4             - Pick-Up                 2022         2434
# 5          - 5 door SUV                 2022         2123
# ..                  ...                  ...          ...
# 307        - 5 door SUV                 2016         1300
# 308          5 door SUV                 2016         1531
# 309    5 door hatchback                 2016          890
# 310  - 5 door hatchback                 2016          890
# 311    5 door hatchback                 2016         1387
#
#                  VIN From Which Rating Applies  ... Isofix/i-Size-Rear  \
# 1                        - all Grand Cherokees  ...    Fitted_Standard
# 2                                 - all OMODA5  ...    Fitted_Standard
# 3                             - all Ford Pumas  ...    Fitted_Standard
# 4                   - all double cabin Rangers  ...    Fitted_Standard
# 5                          - SALCP2FX2PH325732  ...    Fitted_Standard
# ..                                         ...  ...                ...
# 307   - all Atecas of the specification tested  ...    Fitted_Standard
# 308  - all Tiguans of the specification tested  ...    Fitted_Standard
# 309                              - all Balenos  ...    Fitted_Standard
# 310                              - all Balenos  ...    Fitted_Standard
# 311                                - all Prius  ...    Fitted_Standard
#
#     Integrated Child Seat-Rear Airbag cut-off switch-Rear  \
# 1                Not_Available             Not_Applicable
# 2                Not_Available             Not_Applicable
# 3                Not_Available             Not_Applicable
# 4                Not_Available             Not_Applicable
# 5                Not_Available             Not_Applicable
# ..                         ...                        ...
# 307              Not_Available             Not_Applicable
# 308              Not_Available             Not_Applicable
# 309              Not_Available             Not_Applicable
# 310              Not_Available             Not_Applicable
# 311              Not_Available             Not_Applicable
#
#     Seatbelt Reminder-Rear    Active Bonnet AEB Vulnerable Road Users  \
# 1          Fitted_Standard    Not_Available           Fitted_Standard
# 2          Fitted_Standard    Not_Available           Fitted_Standard
# 3          Fitted_Standard    Not_Available           Fitted_Standard
# 4          Fitted_Standard    Not_Available           Fitted_Standard
# 5          Fitted_Standard  Fitted_Standard           Fitted_Standard
# ..                     ...              ...                       ...
# 307        Fitted_Standard    Not_Available                       NaN
# 308        Fitted_Standard  Fitted_Standard                       NaN
# 309        Fitted_Standard    Not_Available                       NaN
# 310        Fitted_Standard    Not_Available                       NaN
# 311        Fitted_Standard    Not_Available                       NaN
#
#     AEB Pedestrian - Reverse   AEB Car-to-Car Speed Assistance  \
# 1              Not_Available  Fitted_Standard  Fitted_Standard
# 2            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 3              Not_Available  Fitted_Standard  Fitted_Standard
# 4            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 5              Not_Available  Fitted_Standard  Fitted_Standard
# ..                       ...              ...              ...
# 307                      NaN              NaN  Fitted_Standard
# 308                      NaN              NaN       Not_Fitted
# 309                      NaN              NaN       Not_Fitted
# 310                      NaN              NaN       Not_Fitted
# 311                      NaN              NaN  Fitted_Standard
#
#     Lane Assist System
# 1      Fitted_Standard
# 2      Fitted_Standard
# 3      Fitted_Standard
# 4      Fitted_Standard
# 5      Fitted_Standard
# ..                 ...
# 307         Not_Fitted
# 308    Fitted_Standard
# 309      Not_Available
# 310      Not_Available
# 311    Fitted_Standard
#
# [311 rows x 53 columns]

# %%
df['Vulnerable Road Users'].unique()
# Out:
# array([81., 68., 70., 74., 71., 89., 78., 73., 75., 60., 62., 67., 82.,
#        66., 69., 72., 79., 85., 87., 76., 83., 65., 63., 64., 80., 41.,
#        39., 55., 84., 58., 57., 77., 52., 93., 45., 46., 59., 61., 56.,
#        91., 54., 86., 47., 49., 90., 92., nan])

# %% [markdown]
# ### dealing with Missing values

# %%
# display all cols has a nan values
missing=df.columns[df.isnull().any()]
print(missing)
# Out:
# Index(['Vulnerable Road Users', 'Centre Airbag-Driver',
#        'Centre Airbag-Passenger', 'Centre Airbag-Rear',
#        'AEB Vulnerable Road Users', 'AEB Pedestrian - Reverse',
#        'AEB Car-to-Car'],
#       dtype='object')

# %%
# display how many missing values in missing cols
mis=df[missing].isnull().sum().sort_values(ascending=False)
print(mis)
df[missing].dtypes
# Out:
# Centre Airbag-Driver         185
# Centre Airbag-Passenger      185
# Centre Airbag-Rear           185
# AEB Vulnerable Road Users    184
# AEB Pedestrian - Reverse     184
# AEB Car-to-Car               184
# Vulnerable Road Users         93
# dtype: int64
# Vulnerable Road Users        float64
# Centre Airbag-Driver          object
# Centre Airbag-Passenger       object
# Centre Airbag-Rear            object
# AEB Vulnerable Road Users     object
# AEB Pedestrian - Reverse      object
# AEB Car-to-Car                object
# dtype: object

# %%
# display the percentage of missing values in missing cols
df[missing].isnull().sum()/df.shape[0]
# Out:
# Vulnerable Road Users        0.299035
# Centre Airbag-Driver         0.594855
# Centre Airbag-Passenger      0.594855
# Centre Airbag-Rear           0.594855
# AEB Vulnerable Road Users    0.591640
# AEB Pedestrian - Reverse     0.591640
# AEB Car-to-Car               0.591640
# dtype: float64

# %% [markdown]
# #### -- Numeric Data --
#
# we have only one col

# %%
# impute Vulnerable Road Users col with mean 

m=df['Vulnerable Road Users'].mean()
print(m)
dfCopy=df.copy()
dfCopy['Vulnerable Road Users'] = df['Vulnerable Road Users'].fillna(m)

dfCopy
# Out:
# 70.84862385321101
#      Rate  Adult Occupant  Child Occupant  Vulnerable Road Users  \
# 1       5              84              89              81.000000
# 2       5              87              87              68.000000
# 3       4              75              84              70.000000
# 4       5              84              90              74.000000
# 5       5              84              89              71.000000
# ..    ...             ...             ...                    ...
# 307     5              93              84              70.848624
# 308     5              96              84              70.848624
# 309     3              80              73              70.848624
# 310     4              85              73              70.848624
# 311     5              92              82              70.848624
#
#      Safety Assist                                  Tested Model  \
# 1               81  Jeep Grand Cherokee 2.0 PHEV 'Overland', LHD
# 2               88                        CHERY OMODA5 1.6T, LHD
# 3               69           Ford Puma 1.0 MHEV, 'Titanium', LHD
# 4               84                 VW Amarok 2.0/Ford Ranger 3.0
# 5               85                               Discovery Sport
# ..             ...                                           ...
# 307             60                    SEAT Ateca 1.6 diesel, LHD
# 308             68                 VW Tiguan 2.0 TDI 110 kW, LHD
# 309             25                                 Suzuki Baleno
# 310             43                                 Suzuki Baleno
# 311             85                                  Prius Hybrid
#
#               Body Type  Year Of Publication  Kerb Weight  \
# 1          - 5 door SUV                 2022         2532
# 2                 - SUV                 2022         1423
# 3          - 5 door SUV                 2022         1334
# 4             - Pick-Up                 2022         2434
# 5          - 5 door SUV                 2022         2123
# ..                  ...                  ...          ...
# 307        - 5 door SUV                 2016         1300
# 308          5 door SUV                 2016         1531
# 309    5 door hatchback                 2016          890
# 310  - 5 door hatchback                 2016          890
# 311    5 door hatchback                 2016         1387
#
#                  VIN From Which Rating Applies  ... Isofix/i-Size-Rear  \
# 1                        - all Grand Cherokees  ...    Fitted_Standard
# 2                                 - all OMODA5  ...    Fitted_Standard
# 3                             - all Ford Pumas  ...    Fitted_Standard
# 4                   - all double cabin Rangers  ...    Fitted_Standard
# 5                          - SALCP2FX2PH325732  ...    Fitted_Standard
# ..                                         ...  ...                ...
# 307   - all Atecas of the specification tested  ...    Fitted_Standard
# 308  - all Tiguans of the specification tested  ...    Fitted_Standard
# 309                              - all Balenos  ...    Fitted_Standard
# 310                              - all Balenos  ...    Fitted_Standard
# 311                                - all Prius  ...    Fitted_Standard
#
#     Integrated Child Seat-Rear Airbag cut-off switch-Rear  \
# 1                Not_Available             Not_Applicable
# 2                Not_Available             Not_Applicable
# 3                Not_Available             Not_Applicable
# 4                Not_Available             Not_Applicable
# 5                Not_Available             Not_Applicable
# ..                         ...                        ...
# 307              Not_Available             Not_Applicable
# 308              Not_Available             Not_Applicable
# 309              Not_Available             Not_Applicable
# 310              Not_Available             Not_Applicable
# 311              Not_Available             Not_Applicable
#
#     Seatbelt Reminder-Rear    Active Bonnet AEB Vulnerable Road Users  \
# 1          Fitted_Standard    Not_Available           Fitted_Standard
# 2          Fitted_Standard    Not_Available           Fitted_Standard
# 3          Fitted_Standard    Not_Available           Fitted_Standard
# 4          Fitted_Standard    Not_Available           Fitted_Standard
# 5          Fitted_Standard  Fitted_Standard           Fitted_Standard
# ..                     ...              ...                       ...
# 307        Fitted_Standard    Not_Available                       NaN
# 308        Fitted_Standard  Fitted_Standard                       NaN
# 309        Fitted_Standard    Not_Available                       NaN
# 310        Fitted_Standard    Not_Available                       NaN
# 311        Fitted_Standard    Not_Available                       NaN
#
#     AEB Pedestrian - Reverse   AEB Car-to-Car Speed Assistance  \
# 1              Not_Available  Fitted_Standard  Fitted_Standard
# 2            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 3              Not_Available  Fitted_Standard  Fitted_Standard
# 4            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 5              Not_Available  Fitted_Standard  Fitted_Standard
# ..                       ...              ...              ...
# 307                      NaN              NaN  Fitted_Standard
# 308                      NaN              NaN       Not_Fitted
# 309                      NaN              NaN       Not_Fitted
# 310                      NaN              NaN       Not_Fitted
# 311                      NaN              NaN  Fitted_Standard
#
#     Lane Assist System
# 1      Fitted_Standard
# 2      Fitted_Standard
# 3      Fitted_Standard
# 4      Fitted_Standard
# 5      Fitted_Standard
# ..                 ...
# 307         Not_Fitted
# 308    Fitted_Standard
# 309      Not_Available
# 310      Not_Available
# 311    Fitted_Standard
#
# [311 rows x 53 columns]

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(df['Vulnerable Road Users'], ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(dfCopy['Vulnerable Road Users'], ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()

# %%
dfCopy["AEB Vulnerable Road Users"].unique()
# Out:
# array(['Fitted_Standard', 'Not_Available', 'Not_Fitted', nan],
#       dtype=object)

# %%
print(df['Vulnerable Road Users'].skew())
print(dfCopy['Vulnerable Road Users'].skew())
# Out:
# -0.7495659039444024
# -0.8934288460745293

# %%
sns.boxplot(dfCopy['Vulnerable Road Users'],orient='h')
# Out:
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Vulnerable Road Users'>

# %%
sns.boxplot(df['Vulnerable Road Users'],orient='h')
# Out:
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Vulnerable Road Users'>

# %% [markdown]
# #### -- Categorical Data --

# %%
# impute missing values by adding new category U

missing_cat=['Centre Airbag-Driver',  'Centre Airbag-Passenger', 'Centre Airbag-Rear',
       'AEB Vulnerable Road Users', 'AEB Pedestrian - Reverse',
       'AEB Car-to-Car']


# imputer = KNNImputer(n_neighbors=5, metric='nan_euclidean')
#dfCopy[['Centre Airbag-Driver']] = imputer.fit_transform(dfCopy[['Centre Airbag-Driver']])
#dfCopy[dfCopy[['Centre Airbag-Driver']].isna()].head(5)


# from sklearn.ensemble import KNNImputer
# imputer = KNNImputer(n_neighbors=5, metric='nan_euclidean')

# from missingpy import MissForest
# imputer = MissForest()
# dfCopy['Centre Airbag-Driver'] = imputer.fit_transform(df['Centre Airbag-Driver'])


from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
dfCopy[missing_cat] = imputer.fit_transform(dfCopy[missing_cat])

dfCopy
# Out:
#      Rate  Adult Occupant  Child Occupant  Vulnerable Road Users  \
# 1       5              84              89              81.000000
# 2       5              87              87              68.000000
# 3       4              75              84              70.000000
# 4       5              84              90              74.000000
# 5       5              84              89              71.000000
# ..    ...             ...             ...                    ...
# 307     5              93              84              70.848624
# 308     5              96              84              70.848624
# 309     3              80              73              70.848624
# 310     4              85              73              70.848624
# 311     5              92              82              70.848624
#
#      Safety Assist                                  Tested Model  \
# 1               81  Jeep Grand Cherokee 2.0 PHEV 'Overland', LHD
# 2               88                        CHERY OMODA5 1.6T, LHD
# 3               69           Ford Puma 1.0 MHEV, 'Titanium', LHD
# 4               84                 VW Amarok 2.0/Ford Ranger 3.0
# 5               85                               Discovery Sport
# ..             ...                                           ...
# 307             60                    SEAT Ateca 1.6 diesel, LHD
# 308             68                 VW Tiguan 2.0 TDI 110 kW, LHD
# 309             25                                 Suzuki Baleno
# 310             43                                 Suzuki Baleno
# 311             85                                  Prius Hybrid
#
#               Body Type  Year Of Publication  Kerb Weight  \
# 1          - 5 door SUV                 2022         2532
# 2                 - SUV                 2022         1423
# 3          - 5 door SUV                 2022         1334
# 4             - Pick-Up                 2022         2434
# 5          - 5 door SUV                 2022         2123
# ..                  ...                  ...          ...
# 307        - 5 door SUV                 2016         1300
# 308          5 door SUV                 2016         1531
# 309    5 door hatchback                 2016          890
# 310  - 5 door hatchback                 2016          890
# 311    5 door hatchback                 2016         1387
#
#                  VIN From Which Rating Applies  ... Isofix/i-Size-Rear  \
# 1                        - all Grand Cherokees  ...    Fitted_Standard
# 2                                 - all OMODA5  ...    Fitted_Standard
# 3                             - all Ford Pumas  ...    Fitted_Standard
# 4                   - all double cabin Rangers  ...    Fitted_Standard
# 5                          - SALCP2FX2PH325732  ...    Fitted_Standard
# ..                                         ...  ...                ...
# 307   - all Atecas of the specification tested  ...    Fitted_Standard
# 308  - all Tiguans of the specification tested  ...    Fitted_Standard
# 309                              - all Balenos  ...    Fitted_Standard
# 310                              - all Balenos  ...    Fitted_Standard
# 311                                - all Prius  ...    Fitted_Standard
#
#     Integrated Child Seat-Rear Airbag cut-off switch-Rear  \
# 1                Not_Available             Not_Applicable
# 2                Not_Available             Not_Applicable
# 3                Not_Available             Not_Applicable
# 4                Not_Available             Not_Applicable
# 5                Not_Available             Not_Applicable
# ..                         ...                        ...
# 307              Not_Available             Not_Applicable
# 308              Not_Available             Not_Applicable
# 309              Not_Available             Not_Applicable
# 310              Not_Available             Not_Applicable
# 311              Not_Available             Not_Applicable
#
#     Seatbelt Reminder-Rear    Active Bonnet AEB Vulnerable Road Users  \
# 1          Fitted_Standard    Not_Available           Fitted_Standard
# 2          Fitted_Standard    Not_Available           Fitted_Standard
# 3          Fitted_Standard    Not_Available           Fitted_Standard
# 4          Fitted_Standard    Not_Available           Fitted_Standard
# 5          Fitted_Standard  Fitted_Standard           Fitted_Standard
# ..                     ...              ...                       ...
# 307        Fitted_Standard    Not_Available           Fitted_Standard
# 308        Fitted_Standard  Fitted_Standard           Fitted_Standard
# 309        Fitted_Standard    Not_Available           Fitted_Standard
# 310        Fitted_Standard    Not_Available           Fitted_Standard
# 311        Fitted_Standard    Not_Available           Fitted_Standard
#
#     AEB Pedestrian - Reverse   AEB Car-to-Car Speed Assistance  \
# 1              Not_Available  Fitted_Standard  Fitted_Standard
# 2            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 3              Not_Available  Fitted_Standard  Fitted_Standard
# 4            Fitted_Standard  Fitted_Standard  Fitted_Standard
# 5              Not_Available  Fitted_Standard  Fitted_Standard
# ..                       ...              ...              ...
# 307            Not_Available  Fitted_Standard  Fitted_Standard
# 308            Not_Available  Fitted_Standard       Not_Fitted
# 309            Not_Available  Fitted_Standard       Not_Fitted
# 310            Not_Available  Fitted_Standard       Not_Fitted
# 311            Not_Available  Fitted_Standard  Fitted_Standard
#
#     Lane Assist System
# 1      Fitted_Standard
# 2      Fitted_Standard
# 3      Fitted_Standard
# 4      Fitted_Standard
# 5      Fitted_Standard
# ..                 ...
# 307         Not_Fitted
# 308    Fitted_Standard
# 309      Not_Available
# 310      Not_Available
# 311    Fitted_Standard
#
# [311 rows x 53 columns]

# %%
for col in missing_cat : 
    fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    sns.histplot(df[col], ax=ax[0], kde=True, legend=False)
    ax[0].set_title("Original Data")
    sns.histplot(dfCopy[col], ax=ax[1], kde=True, legend=False)
    ax[1].set_title("Scaled data")
    plt.show()

# %%
# transform object categories to numeric categories

cat_columns = dfCopy.select_dtypes(['object']).columns # all cols has dtypy == object

#make an instance of Label Encoder 
ordinal_encoder = OrdinalEncoder()
dfCopy[cat_columns] = ordinal_encoder.fit_transform(dfCopy[cat_columns]) 

for col in cat_columns:
    dfCopy[col] = dfCopy[col].astype('int64')

dfCopy
# Out:
#      Rate  Adult Occupant  Child Occupant  Vulnerable Road Users  \
# 1       5              84              89              81.000000
# 2       5              87              87              68.000000
# 3       4              75              84              70.000000
# 4       5              84              90              74.000000
# 5       5              84              89              71.000000
# ..    ...             ...             ...                    ...
# 307     5              93              84              70.848624
# 308     5              96              84              70.848624
# 309     3              80              73              70.848624
# 310     4              85              73              70.848624
# 311     5              92              82              70.848624
#
#      Safety Assist  Tested Model  Body Type  Year Of Publication  Kerb Weight  \
# 1               81            97         11                 2022         2532
# 2               88            29         25                 2022         1423
# 3               69            66         11                 2022         1334
# 4               84           221         22                 2022         2434
# 5               85            47         11                 2022         2123
# ..             ...           ...        ...                  ...          ...
# 307             60           190         11                 2016         1300
# 308             68           232         28                 2016         1531
# 309             25           203         29                 2016          890
# 310             43           203         14                 2016          890
# 311             85           176         29                 2016         1387
#
#      VIN From Which Rating Applies  ...  Isofix/i-Size-Rear  \
# 1                              139  ...                   0
# 2                              199  ...                   0
# 3                              125  ...                   0
# 4                              280  ...                   0
# 5                               14  ...                   0
# ..                             ...  ...                 ...
# 307                             60  ...                   0
# 308                            247  ...                   0
# 309                             64  ...                   0
# 310                             64  ...                   0
# 311                            207  ...                   0
#
#      Integrated Child Seat-Rear  Airbag cut-off switch-Rear  \
# 1                             3                           0
# 2                             3                           0
# 3                             3                           0
# 4                             3                           0
# 5                             3                           0
# ..                          ...                         ...
# 307                           3                           0
# 308                           3                           0
# 309                           3                           0
# 310                           3                           0
# 311                           3                           0
#
#      Seatbelt Reminder-Rear  Active Bonnet  AEB Vulnerable Road Users  \
# 1                         0              1                          0
# 2                         0              1                          0
# 3                         0              1                          0
# 4                         0              1                          0
# 5                         0              0                          0
# ..                      ...            ...                        ...
# 307                       0              1                          0
# 308                       0              0                          0
# 309                       0              1                          0
# 310                       0              1                          0
# 311                       0              1                          0
#
#      AEB Pedestrian - Reverse  AEB Car-to-Car  Speed Assistance  \
# 1                           1               0                 1
# 2                           0               0                 1
# 3                           1               0                 1
# 4                           0               0                 1
# 5                           1               0                 1
# ..                        ...             ...               ...
# 307                         1               0                 1
# 308                         1               0                 3
# 309                         1               0                 3
# 310                         1               0                 3
# 311                         1               0                 1
#
#      Lane Assist System
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# 5                     1
# ..                  ...
# 307                   3
# 308                   1
# 309                   2
# 310                   2
# 311                   1
#
# [311 rows x 53 columns]

# %%
dfCopy.isnull().sum()
# Out:
# Rate                               0
# Adult Occupant                     0
# Child Occupant                     0
# Vulnerable Road Users              0
# Safety Assist                      0
# Tested Model                       0
# Body Type                          0
# Year Of Publication                0
# Kerb Weight                        0
# VIN From Which Rating Applies      0
# Class                              0
# Front Airbag-Driver                0
# Belt Pretensioner-Driver           0
# Belt Loadlimiter-Driver            0
# Knee Airbag-Driver                 0
# Side Head Airbag-Driver            0
# Side Chest Airbag-Driver           0
# Side Pelvis Airbag-Driver          0
# Centre Airbag-Driver               0
# Isofix/i-Size-Driver               0
# Integrated Child Seat-Driver       0
# Airbag cut-off switch-Driver       0
# Seatbelt Reminder-Driver           0
# Front Airbag-Passenger             0
# Belt Pretensioner-Passenger        0
# Belt Loadlimiter-Passenger         0
# Knee Airbag-Passenger              0
# Side Head Airbag-Passenger         0
# Side Chest Airbag-Passenger        0
# Side Pelvis Airbag-Passenger       0
# Centre Airbag-Passenger            0
# Isofix/i-Size-Passenger            0
# Integrated Child Seat-Passenger    0
# Airbag cut-off switch-Passenger    0
# Seatbelt Reminder-Passenger        0
# Front Airbag-Rear                  0
# Belt Pretensioner-Rear             0
# Belt Loadlimiter-Rear              0
# Knee Airbag-Rear                   0
# Side Head Airbag-Rear              0
# Side Chest Airbag-Rear             0
# Side Pelvis Airbag-Rear            0
# Centre Airbag-Rear                 0
# Isofix/i-Size-Rear                 0
# Integrated Child Seat-Rear         0
# Airbag cut-off switch-Rear         0
# Seatbelt Reminder-Rear             0
# Active Bonnet                      0
# AEB Vulnerable Road Users          0
# AEB Pedestrian - Reverse           0
# AEB Car-to-Car                     0
# Speed Assistance                   0
# Lane Assist System                 0
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
for col in dfCopy.columns : 
    fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    sns.histplot(df[col], ax=ax[0], kde=True, legend=False)
    ax[0].set_title("Original Data")
    sns.histplot(dfCopy[col], ax=ax[1], kde=True, legend=False)
    ax[1].set_title("Scaled data")
    plt.show()

# %%
for col in dfCopy.columns : 
    # fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    sns.boxplot(dfCopy[col], orient='h')
    ax[1].set_title("Scaled data")
    plt.show()
# Out:
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/maimonah_s/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
dfCopy.to_csv('cleanedDataset.csv')
