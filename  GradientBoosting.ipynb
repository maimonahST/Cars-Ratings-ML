# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# %%
# load dataset

df = pd.read_csv('finalDataset.csv')

df.index.name = 'index'

columns = df.columns
print(columns)

df.head()
# Out:
# Index(['Centre Airbag-Driver', 'Vulnerable Road Users',
#        'Centre Airbag-Passenger', 'Tested Model',
#        'VIN From Which Rating Applies', 'Centre Airbag-Rear', 'Adult Occupant',
#        'Safety Assist', 'Year Of Publication', 'Class', 'Lane Assist System',
#        'Kerb Weight', 'AEB Vulnerable Road Users', 'Isofix/i-Size-Passenger',
#        'Child Occupant', 'Knee Airbag-Rear', 'Front Airbag-Rear', 'Rate'],
#       dtype='object')
#        Centre Airbag-Driver  Vulnerable Road Users  Centre Airbag-Passenger  \
# index
# 0                       2.0                   81.0                      2.0
# 1                       0.0                   68.0                      0.0
# 2                       2.0                   70.0                      2.0
# 3                       0.0                   74.0                      0.0
# 4                       2.0                   71.0                      2.0
#
#        Tested Model  VIN From Which Rating Applies  Centre Airbag-Rear  \
# index
# 0              97.0                          139.0                   0
# 1              29.0                          199.0                   0
# 2              66.0                          125.0                   0
# 3             221.0                          280.0                   0
# 4              47.0                           14.0                   0
#
#        Adult Occupant  Safety Assist  Year Of Publication  Class  \
# index
# 0                84.0           81.0               2022.0    4.0
# 1                87.0           88.0               2022.0   10.0
# 2                75.0           69.0               2022.0   12.0
# 3                84.0           84.0               2022.0    6.0
# 4                84.0           85.0               2022.0    4.0
#
#        Lane Assist System  Kerb Weight  AEB Vulnerable Road Users  \
# index
# 0                     1.0       2532.0                        0.0
# 1                     1.0       1423.0                        0.0
# 2                     1.0       1334.0                        0.0
# 3                     1.0       2434.0                        0.0
# 4                     1.0       2123.0                        0.0
#
#        Isofix/i-Size-Passenger  Child Occupant  Knee Airbag-Rear  \
# index
# 0                          1.0            89.0                 0
# 1                          1.0            87.0                 0
# 2                          1.0            84.0                 0
# 3                          1.0            90.0                 0
# 4                          0.0            89.0                 0
#
#        Front Airbag-Rear  Rate
# index
# 0                      0   5.0
# 1                      0   5.0
# 2                      0   4.0
# 3                      0   5.0
# 4                      0   5.0

# %%
X = df.iloc[:, : -2 ]
y = df.loc[: ,['Rate']]


# Split dataset to 80% for train and 20% for test

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=0, train_size = .8)


# train dataset
train = pd.concat([X_train,y_train], axis=1, ignore_index=False )
train.head()


# test dataset
test = pd.concat([X_test,y_test], axis=1, ignore_index=False )
test.head()

# save train and test as csv files 

train.to_csv('Train.csv')
test.to_csv('Test.csv')

# %%
train = pd.concat([X_train,y_train], axis=1, ignore_index=False )
train.head()
# Out:
#        Centre Airbag-Driver  Vulnerable Road Users  Centre Airbag-Passenger  \
# index
# 21                      0.0              74.000000                      2.0
# 263                     0.0              70.848624                      0.0
# 120                     0.0              63.000000                      0.0
# 45                      2.0              66.000000                      2.0
# 90                      2.0              41.000000                      2.0
#
#        Tested Model  VIN From Which Rating Applies  Centre Airbag-Rear  \
# index
# 21            221.0                          279.0                   0
# 263           185.0                          169.0                   0
# 120           107.0                          290.0                   1
# 45            191.0                           16.0                   0
# 90            187.0                          277.0                   0
#
#        Adult Occupant  Safety Assist  Year Of Publication  Class  \
# index
# 21               84.0           84.0               2022.0    6.0
# 263              90.0           75.0               2017.0    4.0
# 120              82.0           87.0               2020.0    5.0
# 45               83.0           70.0               2022.0    8.0
# 90               43.0           14.0               2021.0   12.0
#
#        Lane Assist System  Kerb Weight  AEB Vulnerable Road Users  \
# index
# 21                    1.0       2434.0                        0.0
# 263                   1.0       1623.0                        0.0
# 120                   1.0       1847.0                        0.0
# 45                    1.0       1079.0                        0.0
# 90                    3.0       1563.0                        2.0
#
#        Isofix/i-Size-Passenger  Child Occupant  Knee Airbag-Rear  Rate
# index
# 21                         1.0            90.0                 0   5.0
# 263                        1.0            79.0                 1   5.0
# 120                        1.0            85.0                 0   5.0
# 45                         1.0            82.0                 0   5.0
# 90                         0.0            52.0                 0   0.0
